# %% [markdown]
# ### 중국어 mislabel 수정 (좌표 순서 -- 좌상단 우상단 우하단 좌하단)

# %%
import json
import numpy as np
import os

# JSON 파일 경로
json_path = '/data/ephemeral/data/chinese_receipt/ufo/train.json'

# JSON 파일 읽기
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

def correct_points(points):
    # points를 NumPy 배열로 변환
    points = np.array(points)

    # 좌상단 점 찾기
    top_left_idx = np.argmin(points[:, 1])  # y 좌표가 가장 작은 인덱스
    top_left = points[top_left_idx]

    # 나머지 점들의 인덱스
    remaining_indices = [i for i in range(4) if i != top_left_idx]

    # 나머지 점들을 오른쪽으로 정렬
    top_right_idx = remaining_indices[0] if points[remaining_indices[0], 0] > top_left[0] else remaining_indices[1]
    bottom_right_idx = remaining_indices[1] if top_right_idx == remaining_indices[0] else remaining_indices[0]

    # 좌하단 점 찾기
    bottom_left_idx = [i for i in remaining_indices if i not in (top_right_idx, bottom_right_idx)][0]

    # 올바른 순서로 재배치
    corrected_points = [top_left.tolist(), points[top_right_idx].tolist(), points[bottom_right_idx].tolist(), points[bottom_left_idx].tolist()]
    
    return corrected_points

# 레이블 순서 확인 및 수정
for image_id, image_info in data.get('images', {}).items():
    for word_id, word_info in image_info.get('words', {}).items():
        original_points = word_info['points']
        corrected_points = correct_points(original_points)
        
        # 원래 점과 수정된 점을 비교하여 변경사항이 있는지 확인
        if not np.array_equal(np.array(original_points), np.array(corrected_points)):
            print(f"Correcting points for image: {image_id}, word: {word_id}")
            word_info['points'] = corrected_points

# 수정된 JSON 파일 저장
corrected_json_path = '/data/ephemeral/data/chinese_receipt/ufo/train_corrected.json'
with open(corrected_json_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Corrected JSON saved to: {corrected_json_path}")
# Out:
# Correcting points for image: extractor.zh.in_house.appen_000692_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000692_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000692_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000692_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0052
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0071
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0075
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0076
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0079
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0091
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0098
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0099
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0103
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0107
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0130
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0134
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0138
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0142
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0146
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0150
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0151
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0163
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0167
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0172
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0176
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0179
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0181
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0182
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0183
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0184
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0185
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0187
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0192
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0196
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0197
# Correcting points for image: extractor.zh.in_house.appen_000660_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000660_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000660_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000660_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000660_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000660_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0025
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0025
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0025
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0055
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0057
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0058
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0025
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0052
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0053
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0054
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0055
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0057
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0058
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0060
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0062
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0063
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0064
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0069
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0071
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0072
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0061
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0082
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0084
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0087
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0088
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0090
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0093
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0095
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0098
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0099
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0103
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0104
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0106
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0107
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0108
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0109
# Correcting points for image: extractor.zh.in_house.appen2_001047_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen2_001047_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0062
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0063
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0064
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0065
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0066
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0067
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0068
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0069
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0070
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0071
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0072
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0074
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0075
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0076
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0077
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0025
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0026
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0053
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0055
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0060
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0067
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0068
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0069
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0070
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0063
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0064
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0070
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0072
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0074
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0075
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0079
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0080
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0081
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0082
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0085
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0086
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0087
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0088
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0090
# Correcting points for image: extractor.zh.in_house.appen_000825_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000825_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000825_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0025
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0026
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0043
# ...
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0052
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0053
# Correcting points for image: extractor.zh.in_house.appen_000701_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000701_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000701_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000701_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000635_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000635_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000635_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000700_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000700_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000700_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000700_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000700_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0026
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0070
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0071
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0061
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0065
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0066
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0067
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0069
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0070
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0071
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0072
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0074
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0075
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0076
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0053
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0054
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0058
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0060
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0061
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0063
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0066
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0068
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0069
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0070
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0071
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0074
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0075
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0052
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0057
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0060
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0061
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0062
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0065
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0067
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0070
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0075
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0076
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0079
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0080
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0083
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0084
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0085
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0086
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0087
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0097
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0103
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0105
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0106
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0108
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0118
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0120
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0124
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0131
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0133
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0134
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0144
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0147
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0151
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0157
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0160
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0163
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0169
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0171
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0174
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0186
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0193
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0195
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0196
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0198
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0203
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0205
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0208
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0210
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0212
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0213
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0214
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0215
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0216
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0219
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0220
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0222
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0226
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0228
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0231
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0233
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0234
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0235
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0237
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0238
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0239
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0240
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0052
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0055
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0057
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0060
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0062
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0065
# Corrected JSON saved to: /data/ephemeral/data/chinese_receipt/ufo/train_corrected.json

# %% [markdown]
# ### 일본어

# %%
import json
import numpy as np
import os

# JSON 파일 경로
json_path = '/data/ephemeral/data/japanese_receipt/ufo/train.json'

# JSON 파일 읽기
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

def correct_points(points):
    # points를 NumPy 배열로 변환
    points = np.array(points)

    # 좌상단 점 찾기
    top_left_idx = np.argmin(points[:, 1])  # y 좌표가 가장 작은 인덱스
    top_left = points[top_left_idx]

    # 나머지 점들의 인덱스
    remaining_indices = [i for i in range(4) if i != top_left_idx]

    # 나머지 점들을 오른쪽으로 정렬
    top_right_idx = remaining_indices[0] if points[remaining_indices[0], 0] > top_left[0] else remaining_indices[1]
    bottom_right_idx = remaining_indices[1] if top_right_idx == remaining_indices[0] else remaining_indices[0]

    # 좌하단 점 찾기
    bottom_left_idx = [i for i in remaining_indices if i not in (top_right_idx, bottom_right_idx)][0]

    # 올바른 순서로 재배치
    corrected_points = [top_left.tolist(), points[top_right_idx].tolist(), points[bottom_right_idx].tolist(), points[bottom_left_idx].tolist()]
    
    return corrected_points

# 레이블 순서 확인 및 수정
for image_id, image_info in data.get('images', {}).items():
    for word_id, word_info in image_info.get('words', {}).items():
        original_points = word_info['points']
        corrected_points = correct_points(original_points)
        
        # 원래 점과 수정된 점을 비교하여 변경사항이 있는지 확인
        if not np.array_equal(np.array(original_points), np.array(corrected_points)):
            print(f"Correcting points for image: {image_id}, word: {word_id}")
            word_info['points'] = corrected_points

# 수정된 JSON 파일 저장
corrected_json_path = '/data/ephemeral/data/japanese_receipt/ufo/train_corrected.json'
with open(corrected_json_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Corrected JSON saved to: {corrected_json_path}")

# %% [markdown]
# ### 태국어

# %%
import json
import numpy as np
import os

# JSON 파일 경로
json_path = '/data/ephemeral/data/thai_receipt/ufo/train.json'

# JSON 파일 읽기
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

def correct_points(points):
    # points를 NumPy 배열로 변환
    points = np.array(points)

    # 좌상단 점 찾기
    top_left_idx = np.argmin(points[:, 1])  # y 좌표가 가장 작은 인덱스
    top_left = points[top_left_idx]

    # 나머지 점들의 인덱스
    remaining_indices = [i for i in range(4) if i != top_left_idx]

    # 나머지 점들을 오른쪽으로 정렬
    top_right_idx = remaining_indices[0] if points[remaining_indices[0], 0] > top_left[0] else remaining_indices[1]
    bottom_right_idx = remaining_indices[1] if top_right_idx == remaining_indices[0] else remaining_indices[0]

    # 좌하단 점 찾기
    bottom_left_idx = [i for i in remaining_indices if i not in (top_right_idx, bottom_right_idx)][0]

    # 올바른 순서로 재배치
    corrected_points = [top_left.tolist(), points[top_right_idx].tolist(), points[bottom_right_idx].tolist(), points[bottom_left_idx].tolist()]
    
    return corrected_points

# 레이블 순서 확인 및 수정
for image_id, image_info in data.get('images', {}).items():
    for word_id, word_info in image_info.get('words', {}).items():
        original_points = word_info['points']
        corrected_points = correct_points(original_points)
        
        # 원래 점과 수정된 점을 비교하여 변경사항이 있는지 확인
        if not np.array_equal(np.array(original_points), np.array(corrected_points)):
            print(f"Correcting points for image: {image_id}, word: {word_id}")
            word_info['points'] = corrected_points

# 수정된 JSON 파일 저장
corrected_json_path = '/data/ephemeral/data/thai_receipt/ufo/train_corrected.json'
with open(corrected_json_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Corrected JSON saved to: {corrected_json_path}")

# %% [markdown]
# ### 베트남어

# %%
import json
import numpy as np
import os

# JSON 파일 경로
json_path = '/data/ephemeral/data/vietnamese_receipt/ufo/train.json'

# JSON 파일 읽기
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

def correct_points(points):
    # points를 NumPy 배열로 변환
    points = np.array(points)

    # 좌상단 점 찾기
    top_left_idx = np.argmin(points[:, 1])  # y 좌표가 가장 작은 인덱스
    top_left = points[top_left_idx]

    # 나머지 점들의 인덱스
    remaining_indices = [i for i in range(4) if i != top_left_idx]

    # 나머지 점들을 오른쪽으로 정렬
    top_right_idx = remaining_indices[0] if points[remaining_indices[0], 0] > top_left[0] else remaining_indices[1]
    bottom_right_idx = remaining_indices[1] if top_right_idx == remaining_indices[0] else remaining_indices[0]

    # 좌하단 점 찾기
    bottom_left_idx = [i for i in remaining_indices if i not in (top_right_idx, bottom_right_idx)][0]

    # 올바른 순서로 재배치
    corrected_points = [top_left.tolist(), points[top_right_idx].tolist(), points[bottom_right_idx].tolist(), points[bottom_left_idx].tolist()]
    
    return corrected_points

# 레이블 순서 확인 및 수정
for image_id, image_info in data.get('images', {}).items():
    for word_id, word_info in image_info.get('words', {}).items():
        original_points = word_info['points']
        corrected_points = correct_points(original_points)
        
        # 원래 점과 수정된 점을 비교하여 변경사항이 있는지 확인
        if not np.array_equal(np.array(original_points), np.array(corrected_points)):
            print(f"Correcting points for image: {image_id}, word: {word_id}")
            word_info['points'] = corrected_points

# 수정된 JSON 파일 저장
corrected_json_path = '/data/ephemeral/data/vietnamese_receipt/ufo/train_corrected.json'
with open(corrected_json_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Corrected JSON saved to: {corrected_json_path}")
