# %% [markdown]
# ### 중국어 mislabel 수정 (좌표 순서 -- 좌상단 우상단 우하단 좌하단)

# %%
import json
import numpy as np

# JSON 파일 경로
json_path = '/data/ephemeral/code/data/chinese_receipt/ufo/train.json'

# JSON 파일 읽기
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

def correct_points(points):
    # points를 NumPy 배열로 변환
    points = np.array(points)

    left_points = points[np.argsort(points[:, 0])][:2]
    right_points = points[np.argsort(points[:, 0])][-2:]

    # 좌측 점들 중 y 값이 작은 점이 좌상단, 큰 점이 좌하단
    top_left = left_points[np.argmin(left_points[:, 1])]
    bottom_left = left_points[np.argmax(left_points[:, 1])]

    # 우측 점들 중 y 값이 작은 점이 우상단, 큰 점이 우하단
    top_right = right_points[np.argmin(right_points[:, 1])]
    bottom_right = right_points[np.argmax(right_points[:, 1])]

    # 올바른 순서로 재배치
    corrected_points = [top_left.tolist(), top_right.tolist(), bottom_right.tolist(), bottom_left.tolist()]
    
    return corrected_points

# 레이블 순서 확인 및 수정
for image_id, image_info in data.get('images', {}).items():
    for word_id, word_info in image_info.get('words', {}).items():
        original_points = word_info['points']
        corrected_points = correct_points(original_points)
        
        # 원래 점과 수정된 점을 비교하여 변경사항이 있는지 확인
        if not np.array_equal(np.array(original_points), np.array(corrected_points)):
            print(f"Correcting points for image: {image_id}, word: {word_id}")
            word_info['points'] = corrected_points

# 수정된 JSON 파일 저장
corrected_json_path = '/data/ephemeral/code/data/chinese_receipt/ufo/train_corrected.json'
with open(corrected_json_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Corrected JSON saved to: {corrected_json_path}")
# Out:
# Correcting points for image: extractor.zh.in_house.appen_000692_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000692_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000692_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000692_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000835_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000849_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000389_page0001.jpg, word: 0052
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0071
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0075
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0079
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0091
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0098
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0099
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0103
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0107
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0130
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0134
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0138
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0142
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0146
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0150
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0167
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0181
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0182
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0184
# Correcting points for image: extractor.zh.in_house.appen_000333_page0001.jpg, word: 0197
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000888_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000771_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000847_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000497_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000113_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000684_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000801_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0060
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0064
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0065
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0067
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0069
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0072
# Correcting points for image: extractor.zh.in_house.appen_000314_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000112_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000539_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000587_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000104_page0001.jpg, word: 0087
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000090_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000486_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000736_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000867_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0055
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000255_page0001.jpg, word: 0060
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0070
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0074
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0081
# Correcting points for image: extractor.zh.in_house.appen_000224_page0001.jpg, word: 0089
# Correcting points for image: extractor.zh.in_house.appen_000825_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000825_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000388_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000597_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000185_page0001.jpg, word: 0057
# Correcting points for image: extractor.zh.in_house.appen_000124_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000124_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000773_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000086_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000086_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0052
# Correcting points for image: extractor.zh.in_house.appen_000287_page0001.jpg, word: 0053
# Correcting points for image: extractor.zh.in_house.appen_000984_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000984_page0001.jpg, word: 0058
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0054
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0057
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0061
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0075
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0077
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0079
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0081
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0085
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0089
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0091
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0096
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0100
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0115
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0117
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0119
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0121
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0122
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0123
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0124
# Correcting points for image: extractor.zh.in_house.appen_000054_page0001.jpg, word: 0125
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0082
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0088
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0089
# Correcting points for image: extractor.zh.in_house.appen_000060_page0001.jpg, word: 0090
# Correcting points for image: extractor.zh.in_house.appen_000547_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000547_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000725_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000725_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000725_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000725_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000725_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000386_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000386_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000386_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000386_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000386_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000386_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000386_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000426_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000426_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000426_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000426_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000426_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000426_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000751_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000751_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000751_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000211_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000211_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000211_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000211_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen2_001066_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000118_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000118_page0001.jpg, word: 0060
# Correcting points for image: extractor.zh.in_house.appen_000702_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000702_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000702_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000702_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen2_001081_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen2_001081_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen2_001081_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen2_001081_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen2_001081_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen2_001081_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen2_001081_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen2_001063_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen2_001063_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen2_001063_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen2_001063_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen2_001063_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen2_001063_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen2_001063_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen2_001063_page0001.jpg, word: 0052
# Correcting points for image: extractor.zh.in_house.appen2_001063_page0001.jpg, word: 0058
# Correcting points for image: extractor.zh.in_house.appen_000580_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000580_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000580_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000580_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000580_page0001.jpg, word: 0053
# Correcting points for image: extractor.zh.in_house.appen_000580_page0001.jpg, word: 0062
# Correcting points for image: extractor.zh.in_house.appen_000580_page0001.jpg, word: 0063
# Correcting points for image: extractor.zh.in_house.appen_000580_page0001.jpg, word: 0066
# Correcting points for image: extractor.zh.in_house.appen_000580_page0001.jpg, word: 0068
# Correcting points for image: extractor.zh.in_house.appen_000606_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000606_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000606_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000606_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000606_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen_000606_page0001.jpg, word: 0063
# Correcting points for image: extractor.zh.in_house.appen_000606_page0001.jpg, word: 0066
# Correcting points for image: extractor.zh.in_house.appen_000606_page0001.jpg, word: 0067
# Correcting points for image: extractor.zh.in_house.appen_000606_page0001.jpg, word: 0068
# Correcting points for image: extractor.zh.in_house.appen_000767_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000767_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000767_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000767_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000767_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000767_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000767_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000767_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000695_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000273_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000273_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000273_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000273_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000273_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000273_page0001.jpg, word: 0055
# Correcting points for image: extractor.zh.in_house.appen_000529_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000529_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000397_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000397_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000397_page0001.jpg, word: 0025
# Correcting points for image: extractor.zh.in_house.appen_000397_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000397_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000689_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000689_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000689_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000689_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen_000689_page0001.jpg, word: 0058
# Correcting points for image: extractor.zh.in_house.appen_000689_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000689_page0001.jpg, word: 0061
# Correcting points for image: extractor.zh.in_house.appen_000689_page0001.jpg, word: 0066
# Correcting points for image: extractor.zh.in_house.appen_000689_page0001.jpg, word: 0068
# Correcting points for image: extractor.zh.in_house.appen_000088_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000088_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000088_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000088_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000363_page0001.jpg, word: 0034
# Correcting points for image: extractor.zh.in_house.appen_000363_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000363_page0001.jpg, word: 0038
# Correcting points for image: extractor.zh.in_house.appen_000363_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000363_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000326_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000326_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000326_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000326_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000326_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000326_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000326_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000326_page0001.jpg, word: 0049
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0050
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0054
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0062
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0070
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0110
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0113
# Correcting points for image: extractor.zh.in_house.appen_000983_page0001.jpg, word: 0123
# Correcting points for image: extractor.zh.in_house.appen_000346_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000346_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000346_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000346_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000346_page0001.jpg, word: 0031
# Correcting points for image: extractor.zh.in_house.appen_000346_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000346_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000140_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000140_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000140_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000140_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000008_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000651_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000651_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000651_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000651_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000651_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000651_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000752_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000752_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000752_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000752_page0001.jpg, word: 0023
# Correcting points for image: extractor.zh.in_house.appen_000752_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000752_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen2_001082_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen2_001082_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen2_001082_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen2_001082_page0001.jpg, word: 0086
# Correcting points for image: extractor.zh.in_house.appen2_001082_page0001.jpg, word: 0087
# Correcting points for image: extractor.zh.in_house.appen2_001082_page0001.jpg, word: 0099
# Correcting points for image: extractor.zh.in_house.appen_000171_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000561_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000561_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000561_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000561_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000561_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000928_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000928_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000928_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000928_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000928_page0001.jpg, word: 0058
# Correcting points for image: extractor.zh.in_house.appen_000928_page0001.jpg, word: 0062
# Correcting points for image: extractor.zh.in_house.appen_000928_page0001.jpg, word: 0073
# Correcting points for image: extractor.zh.in_house.appen_000058_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000058_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000985_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000985_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000985_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000985_page0001.jpg, word: 0083
# Correcting points for image: extractor.zh.in_house.appen_000985_page0001.jpg, word: 0088
# Correcting points for image: extractor.zh.in_house.appen_000985_page0001.jpg, word: 0092
# Correcting points for image: extractor.zh.in_house.appen_000985_page0001.jpg, word: 0093
# Correcting points for image: extractor.zh.in_house.appen_000985_page0001.jpg, word: 0094
# Correcting points for image: extractor.zh.in_house.appen_000714_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000714_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000714_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000714_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000714_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000714_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000714_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000016_page0001.jpg, word: 0055
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0025
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0026
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0045
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0054
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0058
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0062
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0063
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0067
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0069
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0071
# Correcting points for image: extractor.zh.in_house.appen_000963_page0001.jpg, word: 0072
# Correcting points for image: extractor.zh.in_house.appen_000663_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000663_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000663_page0001.jpg, word: 0043
# Correcting points for image: extractor.zh.in_house.appen_000614_page0001.jpg, word: 0003
# Correcting points for image: extractor.zh.in_house.appen_000614_page0001.jpg, word: 0061
# Correcting points for image: extractor.zh.in_house.appen_000614_page0001.jpg, word: 0064
# Correcting points for image: extractor.zh.in_house.appen_000614_page0001.jpg, word: 0071
# Correcting points for image: extractor.zh.in_house.appen_000614_page0001.jpg, word: 0074
# Correcting points for image: extractor.zh.in_house.appen_001018_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000487_page0001.jpg, word: 0007
# Correcting points for image: extractor.zh.in_house.appen_000487_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000487_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000487_page0001.jpg, word: 0037
# Correcting points for image: extractor.zh.in_house.appen_000361_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000361_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000361_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000361_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0036
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0054
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0055
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0075
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0085
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0088
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0092
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0094
# Correcting points for image: extractor.zh.in_house.appen_000266_page0001.jpg, word: 0097
# Correcting points for image: extractor.zh.in_house.appen_000121_page0001.jpg, word: 0010
# Correcting points for image: extractor.zh.in_house.appen_000121_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000121_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000121_page0001.jpg, word: 0048
# Correcting points for image: extractor.zh.in_house.appen_000121_page0001.jpg, word: 0054
# Correcting points for image: extractor.zh.in_house.appen_000330_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000330_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0004
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0018
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0024
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0032
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0039
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0054
# Correcting points for image: extractor.zh.in_house.appen_000188_page0001.jpg, word: 0057
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0005
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0006
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0013
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0021
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0027
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0080
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0142
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0143
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0146
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0150
# Correcting points for image: extractor.zh.in_house.appen_000047_page0001.jpg, word: 0151
# Correcting points for image: extractor.zh.in_house.appen2_001050_page0001.jpg, word: 0020
# Correcting points for image: extractor.zh.in_house.appen2_001050_page0001.jpg, word: 0040
# Correcting points for image: extractor.zh.in_house.appen2_001050_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen2_001050_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0008
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0016
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0022
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0035
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0046
# Correcting points for image: extractor.zh.in_house.appen_000858_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0030
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0051
# Correcting points for image: extractor.zh.in_house.appen_000976_page0001.jpg, word: 0053
# Correcting points for image: extractor.zh.in_house.appen_000701_page0001.jpg, word: 0014
# Correcting points for image: extractor.zh.in_house.appen_000701_page0001.jpg, word: 0029
# Correcting points for image: extractor.zh.in_house.appen_000635_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000635_page0001.jpg, word: 0047
# Correcting points for image: extractor.zh.in_house.appen_000700_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0015
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0033
# Correcting points for image: extractor.zh.in_house.appen_000705_page0001.jpg, word: 0056
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0002
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0009
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0028
# Correcting points for image: extractor.zh.in_house.appen_000991_page0001.jpg, word: 0066
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0017
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0060
# Correcting points for image: extractor.zh.in_house.appen2_001074_page0001.jpg, word: 0068
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0001
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0011
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0012
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0019
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0044
# Correcting points for image: extractor.zh.in_house.appen_000030_page0001.jpg, word: 0213
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0041
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0042
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0052
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0057
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0059
# Correcting points for image: extractor.zh.in_house.appen_000755_page0001.jpg, word: 0065
# Corrected JSON saved to: /data/ephemeral/code/data/chinese_receipt/ufo/train_corrected.json

# %% [markdown]
# ### 일본어

# %%
import json
import numpy as np

# JSON 파일 경로
json_path = '/data/ephemeral/code/data/japanese_receipt/ufo/train.json'

# JSON 파일 읽기
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

def correct_points(points):
    # points를 NumPy 배열로 변환
    points = np.array(points)

    left_points = points[np.argsort(points[:, 0])][:2]
    right_points = points[np.argsort(points[:, 0])][-2:]

    # 좌측 점들 중 y 값이 작은 점이 좌상단, 큰 점이 좌하단
    top_left = left_points[np.argmin(left_points[:, 1])]
    bottom_left = left_points[np.argmax(left_points[:, 1])]

    # 우측 점들 중 y 값이 작은 점이 우상단, 큰 점이 우하단
    top_right = right_points[np.argmin(right_points[:, 1])]
    bottom_right = right_points[np.argmax(right_points[:, 1])]

    # 올바른 순서로 재배치
    corrected_points = [top_left.tolist(), top_right.tolist(), bottom_right.tolist(), bottom_left.tolist()]
    
    return corrected_points

# 레이블 순서 확인 및 수정
for image_id, image_info in data.get('images', {}).items():
    for word_id, word_info in image_info.get('words', {}).items():
        original_points = word_info['points']
        corrected_points = correct_points(original_points)
        
        # 원래 점과 수정된 점을 비교하여 변경사항이 있는지 확인
        if not np.array_equal(np.array(original_points), np.array(corrected_points)):
            print(f"Correcting points for image: {image_id}, word: {word_id}")
            word_info['points'] = corrected_points

# 수정된 JSON 파일 저장
corrected_json_path = '/data/ephemeral/code/data/japanese_receipt/ufo/train_corrected.json'
with open(corrected_json_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Corrected JSON saved to: {corrected_json_path}")
# Out:
# Correcting points for image: extractor.ja.in_house.appen_000911_page0001.jpg, word: 0001
# Correcting points for image: extractor.ja.in_house.appen_000911_page0001.jpg, word: 0003
# Correcting points for image: extractor.ja.in_house.appen_000911_page0001.jpg, word: 0044
# Correcting points for image: extractor.ja.in_house.appen_000911_page0001.jpg, word: 0050
# Correcting points for image: extractor.ja.in_house.appen_000723_page0001.jpg, word: 0008
# Correcting points for image: extractor.ja.in_house.appen_000723_page0001.jpg, word: 0015
# Correcting points for image: extractor.ja.in_house.appen_000723_page0001.jpg, word: 0044
# Correcting points for image: extractor.ja.in_house.appen_000723_page0001.jpg, word: 0046
# Correcting points for image: extractor.ja.in_house.appen_000723_page0001.jpg, word: 0051
# Correcting points for image: extractor.ja.in_house.appen_000618_page0001.jpg, word: 0002
# Correcting points for image: extractor.ja.in_house.appen_000618_page0001.jpg, word: 0043
# Correcting points for image: extractor.ja.in_house.appen_000618_page0001.jpg, word: 0047
# Correcting points for image: extractor.ja.in_house.appen_000719_page0001.jpg, word: 0002
# Correcting points for image: extractor.ja.in_house.appen_000868_page0001.jpg, word: 0001
# Correcting points for image: extractor.ja.in_house.appen_000843_page0001.jpg, word: 0004
# Correcting points for image: extractor.ja.in_house.appen_000351_page0001.jpg, word: 0081
# Correcting points for image: extractor.ja.in_house.appen_000351_page0001.jpg, word: 0090
# Correcting points for image: extractor.ja.in_house.appen_000993_page0001.jpg, word: 0052
# Correcting points for image: extractor.ja.in_house.appen_000942_page0001.jpg, word: 0005
# Correcting points for image: extractor.ja.in_house.appen_000942_page0001.jpg, word: 0077
# Correcting points for image: extractor.ja.in_house.appen_000942_page0001.jpg, word: 0078
# Correcting points for image: extractor.ja.in_house.appen_000942_page0001.jpg, word: 0080
# Correcting points for image: extractor.ja.in_house.appen_000317_page0001.jpg, word: 0003
# Correcting points for image: extractor.ja.in_house.appen_000317_page0001.jpg, word: 0006
# Correcting points for image: extractor.ja.in_house.appen_000317_page0001.jpg, word: 0008
# Correcting points for image: extractor.ja.in_house.appen_000317_page0001.jpg, word: 0013
# Correcting points for image: extractor.ja.in_house.appen_000317_page0001.jpg, word: 0052
# Correcting points for image: extractor.ja.in_house.appen_000183_page0001.jpg, word: 0017
# Correcting points for image: extractor.ja.in_house.appen_000183_page0001.jpg, word: 0027
# Correcting points for image: extractor.ja.in_house.appen_000783_page0001.jpg, word: 0008
# Correcting points for image: extractor.ja.in_house.appen_000783_page0001.jpg, word: 0052
# Correcting points for image: extractor.ja.in_house.appen_000084_page0001.jpg, word: 0030
# Correcting points for image: extractor.ja.in_house.appen_000084_page0001.jpg, word: 0054
# Correcting points for image: extractor.ja.in_house.appen_000084_page0001.jpg, word: 0057
# Correcting points for image: extractor.ja.in_house.appen_000084_page0001.jpg, word: 0074
# Correcting points for image: extractor.ja.in_house.appen_000084_page0001.jpg, word: 0081
# Correcting points for image: extractor.ja.in_house.appen_000084_page0001.jpg, word: 0092
# Correcting points for image: extractor.ja.in_house.appen_000084_page0001.jpg, word: 0101
# Correcting points for image: extractor.ja.in_house.appen_000484_page0001.jpg, word: 0001
# Correcting points for image: extractor.ja.in_house.appen_000484_page0001.jpg, word: 0019
# Correcting points for image: extractor.ja.in_house.appen_000484_page0001.jpg, word: 0027
# Correcting points for image: extractor.ja.in_house.appen_000484_page0001.jpg, word: 0028
# Correcting points for image: extractor.ja.in_house.appen_000484_page0001.jpg, word: 0029
# Correcting points for image: extractor.ja.in_house.appen_000484_page0001.jpg, word: 0030
# Correcting points for image: extractor.ja.in_house.appen_000484_page0001.jpg, word: 0031
# Correcting points for image: extractor.ja.in_house.appen_000484_page0001.jpg, word: 0032
# Correcting points for image: extractor.ja.in_house.appen_000484_page0001.jpg, word: 0033
# Correcting points for image: extractor.ja.in_house.appen_000798_page0001.jpg, word: 0007
# Correcting points for image: extractor.ja.in_house.appen_000494_page0001.jpg, word: 0011
# Correcting points for image: extractor.ja.in_house.appen_000498_page0001.jpg, word: 0083
# Correcting points for image: extractor.ja.in_house.appen_000498_page0001.jpg, word: 0093
# Corrected JSON saved to: /data/ephemeral/code/data/japanese_receipt/ufo/train_corrected.json

# %% [markdown]
# ### 태국어

# %%
import json
import numpy as np

# JSON 파일 경로
json_path = '/data/ephemeral/code/data/thai_receipt/ufo/train.json'

# JSON 파일 읽기
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

def correct_points(points):
    # points를 NumPy 배열로 변환
    points = np.array(points)

    left_points = points[np.argsort(points[:, 0])][:2]
    right_points = points[np.argsort(points[:, 0])][-2:]

    # 좌측 점들 중 y 값이 작은 점이 좌상단, 큰 점이 좌하단
    top_left = left_points[np.argmin(left_points[:, 1])]
    bottom_left = left_points[np.argmax(left_points[:, 1])]

    # 우측 점들 중 y 값이 작은 점이 우상단, 큰 점이 우하단
    top_right = right_points[np.argmin(right_points[:, 1])]
    bottom_right = right_points[np.argmax(right_points[:, 1])]

    # 올바른 순서로 재배치
    corrected_points = [top_left.tolist(), top_right.tolist(), bottom_right.tolist(), bottom_left.tolist()]
    
    return corrected_points

# 레이블 순서 확인 및 수정
for image_id, image_info in data.get('images', {}).items():
    for word_id, word_info in image_info.get('words', {}).items():
        original_points = word_info['points']
        corrected_points = correct_points(original_points)
        
        # 원래 점과 수정된 점을 비교하여 변경사항이 있는지 확인
        if not np.array_equal(np.array(original_points), np.array(corrected_points)):
            print(f"Correcting points for image: {image_id}, word: {word_id}")
            word_info['points'] = corrected_points

# 수정된 JSON 파일 저장
corrected_json_path = '/data/ephemeral/code/data/thai_receipt/ufo/train_corrected.json'
with open(corrected_json_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Corrected JSON saved to: {corrected_json_path}")
# Out:
# Correcting points for image: extractor.th.in_house.appen_001003_page0001.jpg, word: 0037
# Correcting points for image: extractor.th.in_house.appen_000750_page0001.jpg, word: 0009
# Correcting points for image: extractor.th.in_house.appen_000750_page0001.jpg, word: 0013
# Correcting points for image: extractor.th.in_house.appen_000750_page0001.jpg, word: 0025
# Correcting points for image: extractor.th.in_house.appen_000750_page0001.jpg, word: 0027
# Correcting points for image: extractor.th.in_house.appen_000750_page0001.jpg, word: 0029
# Correcting points for image: extractor.th.in_house.appen_000750_page0001.jpg, word: 0036
# Correcting points for image: extractor.th.in_house.appen_000403_page0001.jpg, word: 0010
# Correcting points for image: extractor.th.in_house.appen_000318_page0001.jpg, word: 0022
# Correcting points for image: extractor.th.in_house.appen_000576_page0001.jpg, word: 0004
# Correcting points for image: extractor.th.in_house.appen_000576_page0001.jpg, word: 0064
# Correcting points for image: extractor.th.in_house.appen_000576_page0001.jpg, word: 0079
# Correcting points for image: extractor.th.in_house.appen_000179_page0001.jpg, word: 0067
# Correcting points for image: extractor.th.in_house.appen_000179_page0001.jpg, word: 0074
# Correcting points for image: extractor.th.in_house.appen_000628_page0001.jpg, word: 0055
# Correcting points for image: extractor.th.in_house.appen_000628_page0001.jpg, word: 0064
# Correcting points for image: extractor.th.in_house.appen_000630_page0001.jpg, word: 0001
# Correcting points for image: extractor.th.in_house.appen_000630_page0001.jpg, word: 0002
# Correcting points for image: extractor.th.in_house.appen_000630_page0001.jpg, word: 0064
# Correcting points for image: extractor.th.in_house.appen_000630_page0001.jpg, word: 0071
# Correcting points for image: extractor.th.in_house.appen_000420_page0001.jpg, word: 0035
# Correcting points for image: extractor.th.in_house.appen_000666_page0001.jpg, word: 0015
# Correcting points for image: extractor.th.in_house.appen_000579_page0001.jpg, word: 0005
# Correcting points for image: extractor.th.in_house.appen_000579_page0001.jpg, word: 0028
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0064
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0072
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0073
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0074
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0077
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0078
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0080
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0081
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0082
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0083
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0090
# Correcting points for image: extractor.th.in_house.appen_000322_page0001.jpg, word: 0093
# Correcting points for image: extractor.th.in_house.appen_000721_page0001.jpg, word: 0066
# Correcting points for image: extractor.th.in_house.appen_000721_page0001.jpg, word: 0068
# Correcting points for image: extractor.th.in_house.appen_000721_page0001.jpg, word: 0077
# Correcting points for image: extractor.th.in_house.appen_000125_page0001.jpg, word: 0020
# Correcting points for image: extractor.th.in_house.appen_000125_page0001.jpg, word: 0061
# Correcting points for image: extractor.th.in_house.appen_000241_page0001.jpg, word: 0053
# Correcting points for image: extractor.th.in_house.appen_000169_page0001.jpg, word: 0002
# Correcting points for image: extractor.th.in_house.appen_000923_page0001.jpg, word: 0082
# Correcting points for image: extractor.th.in_house.appen_000056_page0001.jpg, word: 0063
# Correcting points for image: extractor.th.in_house.appen_000056_page0001.jpg, word: 0074
# Correcting points for image: extractor.th.in_house.appen_000293_page0001.jpg, word: 0065
# Correcting points for image: extractor.th.in_house.appen_000228_page0001.jpg, word: 0060
# Correcting points for image: extractor.th.in_house.appen_000074_page0001.jpg, word: 0001
# Correcting points for image: extractor.th.in_house.appen_000074_page0001.jpg, word: 0003
# Correcting points for image: extractor.th.in_house.appen_000074_page0001.jpg, word: 0004
# Correcting points for image: extractor.th.in_house.appen_000074_page0001.jpg, word: 0005
# Correcting points for image: extractor.th.in_house.appen_000074_page0001.jpg, word: 0050
# Correcting points for image: extractor.th.in_house.appen_000074_page0001.jpg, word: 0060
# Correcting points for image: extractor.th.in_house.appen_000730_page0001.jpg, word: 0029
# Correcting points for image: extractor.th.in_house.appen_000730_page0001.jpg, word: 0038
# Correcting points for image: extractor.th.in_house.appen_000730_page0001.jpg, word: 0054
# Correcting points for image: extractor.th.in_house.appen_000730_page0001.jpg, word: 0058
# Correcting points for image: extractor.th.in_house.appen_000383_page0001.jpg, word: 0023
# Correcting points for image: extractor.th.in_house.appen_000894_page0001.jpg, word: 0043
# Correcting points for image: extractor.th.in_house.appen_000894_page0001.jpg, word: 0065
# Correcting points for image: extractor.th.in_house.appen_000607_page0001.jpg, word: 0001
# Correcting points for image: extractor.th.in_house.appen_000607_page0001.jpg, word: 0006
# Correcting points for image: extractor.th.in_house.appen_000607_page0001.jpg, word: 0007
# Correcting points for image: extractor.th.in_house.appen_000607_page0001.jpg, word: 0031
# Correcting points for image: extractor.th.in_house.appen_000607_page0001.jpg, word: 0085
# Correcting points for image: extractor.th.in_house.appen_000607_page0001.jpg, word: 0113
# Correcting points for image: extractor.th.in_house.appen_000395_page0001.jpg, word: 0026
# Correcting points for image: extractor.th.in_house.appen_000804_page0001.jpg, word: 0064
# Correcting points for image: extractor.th.in_house.appen_000377_page0001.jpg, word: 0001
# Correcting points for image: extractor.th.in_house.appen_000377_page0001.jpg, word: 0008
# Correcting points for image: extractor.th.in_house.appen_000377_page0001.jpg, word: 0012
# Correcting points for image: extractor.th.in_house.appen_000377_page0001.jpg, word: 0037
# Correcting points for image: extractor.th.in_house.appen_000377_page0001.jpg, word: 0042
# Correcting points for image: extractor.th.in_house.appen_000377_page0001.jpg, word: 0056
# Correcting points for image: extractor.th.in_house.appen_000095_page0001.jpg, word: 0062
# Correcting points for image: extractor.th.in_house.appen_000095_page0001.jpg, word: 0064
# Correcting points for image: extractor.th.in_house.appen_000095_page0001.jpg, word: 0078
# Correcting points for image: extractor.th.in_house.appen_000095_page0001.jpg, word: 0079
# Correcting points for image: extractor.th.in_house.appen_000095_page0001.jpg, word: 0081
# Correcting points for image: extractor.th.in_house.appen_000522_page0001.jpg, word: 0038
# Correcting points for image: extractor.th.in_house.appen_000946_page0001.jpg, word: 0023
# Correcting points for image: extractor.th.in_house.appen_000946_page0001.jpg, word: 0059
# Correcting points for image: extractor.th.in_house.appen_000946_page0001.jpg, word: 0062
# Correcting points for image: extractor.th.in_house.appen_000946_page0001.jpg, word: 0070
# Correcting points for image: extractor.th.in_house.appen_000946_page0001.jpg, word: 0076
# Correcting points for image: extractor.th.in_house.appen_000946_page0001.jpg, word: 0078
# Correcting points for image: extractor.th.in_house.appen_000946_page0001.jpg, word: 0079
# Correcting points for image: extractor.th.in_house.appen_000946_page0001.jpg, word: 0081
# Correcting points for image: extractor.th.in_house.appen_000360_page0001.jpg, word: 0012
# Correcting points for image: extractor.th.in_house.appen_000360_page0001.jpg, word: 0043
# Correcting points for image: extractor.th.in_house.appen_000360_page0001.jpg, word: 0050
# Correcting points for image: extractor.th.in_house.appen_000360_page0001.jpg, word: 0056
# Correcting points for image: extractor.th.in_house.appen_000178_page0001.jpg, word: 0088
# Correcting points for image: extractor.th.in_house.appen_000240_page0001.jpg, word: 0020
# Correcting points for image: extractor.th.in_house.appen_000944_page0001.jpg, word: 0061
# Correcting points for image: extractor.th.in_house.appen_000944_page0001.jpg, word: 0068
# Correcting points for image: extractor.th.in_house.appen_000944_page0001.jpg, word: 0072
# Correcting points for image: extractor.th.in_house.appen_000944_page0001.jpg, word: 0073
# Correcting points for image: extractor.th.in_house.appen_000944_page0001.jpg, word: 0076
# Correcting points for image: extractor.th.in_house.appen_000629_page0001.jpg, word: 0003
# Correcting points for image: extractor.th.in_house.appen_000844_page0001.jpg, word: 0005
# Correcting points for image: extractor.th.in_house.appen_000844_page0001.jpg, word: 0058
# Correcting points for image: extractor.th.in_house.appen_000844_page0001.jpg, word: 0068
# Correcting points for image: extractor.th.in_house.appen_000844_page0001.jpg, word: 0070
# Correcting points for image: extractor.th.in_house.appen_000844_page0001.jpg, word: 0078
# Correcting points for image: extractor.th.in_house.appen_000844_page0001.jpg, word: 0081
# Correcting points for image: extractor.th.in_house.appen_000844_page0001.jpg, word: 0091
# Correcting points for image: extractor.th.in_house.appen_000844_page0001.jpg, word: 0093
# Correcting points for image: extractor.th.in_house.appen_000315_page0001.jpg, word: 0018
# Correcting points for image: extractor.th.in_house.appen_000368_page0001.jpg, word: 0003
# Correcting points for image: extractor.th.in_house.appen_000368_page0001.jpg, word: 0007
# Correcting points for image: extractor.th.in_house.appen_000368_page0001.jpg, word: 0008
# Correcting points for image: extractor.th.in_house.appen_000368_page0001.jpg, word: 0080
# Correcting points for image: extractor.th.in_house.appen_000064_page0001.jpg, word: 0020
# Correcting points for image: extractor.th.in_house.appen_000064_page0001.jpg, word: 0040
# Correcting points for image: extractor.th.in_house.appen_000064_page0001.jpg, word: 0045
# Correcting points for image: extractor.th.in_house.appen_000110_page0001.png, word: 0007
# Correcting points for image: extractor.th.in_house.appen_000110_page0001.png, word: 0022
# Correcting points for image: extractor.th.in_house.appen_000110_page0001.png, word: 0038
# Correcting points for image: extractor.th.in_house.appen_000110_page0001.png, word: 0041
# Correcting points for image: extractor.th.in_house.appen_000110_page0001.png, word: 0050
# Correcting points for image: extractor.th.in_house.appen_000110_page0001.png, word: 0070
# Correcting points for image: extractor.th.in_house.appen_000110_page0001.png, word: 0071
# Correcting points for image: extractor.th.in_house.appen_000110_page0001.png, word: 0081
# Correcting points for image: extractor.th.in_house.appen_000110_page0001.png, word: 0082
# Corrected JSON saved to: /data/ephemeral/code/data/thai_receipt/ufo/train_corrected.json

# %% [markdown]
# ### 베트남어

# %%
import json
import numpy as np

# JSON 파일 경로
json_path = '/data/ephemeral/code/data/vietnamese_receipt/ufo/train.json'

# JSON 파일 읽기
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

def correct_points(points):
    # points를 NumPy 배열로 변환
    points = np.array(points)

    left_points = points[np.argsort(points[:, 0])][:2]
    right_points = points[np.argsort(points[:, 0])][-2:]

    # 좌측 점들 중 y 값이 작은 점이 좌상단, 큰 점이 좌하단
    top_left = left_points[np.argmin(left_points[:, 1])]
    bottom_left = left_points[np.argmax(left_points[:, 1])]

    # 우측 점들 중 y 값이 작은 점이 우상단, 큰 점이 우하단
    top_right = right_points[np.argmin(right_points[:, 1])]
    bottom_right = right_points[np.argmax(right_points[:, 1])]

    # 올바른 순서로 재배치
    corrected_points = [top_left.tolist(), top_right.tolist(), bottom_right.tolist(), bottom_left.tolist()]
    
    return corrected_points

# 레이블 순서 확인 및 수정
for image_id, image_info in data.get('images', {}).items():
    for word_id, word_info in image_info.get('words', {}).items():
        original_points = word_info['points']
        corrected_points = correct_points(original_points)
        
        # 원래 점과 수정된 점을 비교하여 변경사항이 있는지 확인
        if not np.array_equal(np.array(original_points), np.array(corrected_points)):
            print(f"Correcting points for image: {image_id}, word: {word_id}")
            word_info['points'] = corrected_points

# 수정된 JSON 파일 저장
corrected_json_path = '/data/ephemeral/code/data/vietnamese_receipt/ufo/train_corrected.json'
with open(corrected_json_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Corrected JSON saved to: {corrected_json_path}")
# Out:
# Correcting points for image: extractor.vi.in_house.appen_000961_page0001.jpg, word: 0065
# Correcting points for image: extractor.vi.in_house.appen_000961_page0001.jpg, word: 0072
# Correcting points for image: extractor.vi.in_house.appen_000961_page0001.jpg, word: 0077
# Correcting points for image: extractor.vi.in_house.appen_000750_page0001.jpg, word: 0020
# Correcting points for image: extractor.vi.in_house.appen_000750_page0001.jpg, word: 0036
# Correcting points for image: extractor.vi.in_house.appen_000750_page0001.jpg, word: 0049
# Correcting points for image: extractor.vi.in_house.appen_000698_page0001.jpg, word: 0036
# Correcting points for image: extractor.vi.in_house.appen_000698_page0001.jpg, word: 0055
# Correcting points for image: extractor.vi.in_house.appen_000698_page0001.jpg, word: 0071
# Correcting points for image: extractor.vi.in_house.appen_000540_page0001.jpg, word: 0068
# Correcting points for image: extractor.vi.in_house.appen_000494_page0001.jpg, word: 0013
# Correcting points for image: extractor.vi.in_house.appen_000494_page0001.jpg, word: 0045
# Correcting points for image: extractor.vi.in_house.appen_000494_page0001.jpg, word: 0051
# Correcting points for image: extractor.vi.in_house.appen_000494_page0001.jpg, word: 0073
# Correcting points for image: extractor.vi.in_house.appen_000494_page0001.jpg, word: 0078
# Correcting points for image: extractor.vi.in_house.appen_000595_page0001.jpg, word: 0002
# Correcting points for image: extractor.vi.in_house.appen_000595_page0001.jpg, word: 0011
# Correcting points for image: extractor.vi.in_house.appen_000646_page0001.jpg, word: 0019
# Correcting points for image: extractor.vi.in_house.appen_000646_page0001.jpg, word: 0045
# Correcting points for image: extractor.vi.in_house.appen_000646_page0001.jpg, word: 0051
# Correcting points for image: extractor.vi.in_house.appen_000025_page0001.jpg, word: 0045
# Correcting points for image: extractor.vi.in_house.appen_000427_page0001.jpg, word: 0017
# Correcting points for image: extractor.vi.in_house.appen_000427_page0001.jpg, word: 0032
# Correcting points for image: extractor.vi.in_house.appen_001008_page0001.jpg, word: 0049
# Correcting points for image: extractor.vi.in_house.appen_001008_page0001.jpg, word: 0066
# Correcting points for image: extractor.vi.in_house.appen_001008_page0001.jpg, word: 0176
# Correcting points for image: extractor.vi.in_house.appen_000373_page0001.jpg, word: 0120
# Correcting points for image: extractor.vi.in_house.appen_000678_page0001.jpg, word: 0023
# Correcting points for image: extractor.vi.in_house.appen_000678_page0001.jpg, word: 0037
# Correcting points for image: extractor.vi.in_house.appen_000478_page0001.jpg, word: 0001
# Correcting points for image: extractor.vi.in_house.appen_000478_page0001.jpg, word: 0002
# Correcting points for image: extractor.vi.in_house.appen_000478_page0001.jpg, word: 0003
# Correcting points for image: extractor.vi.in_house.appen_000478_page0001.jpg, word: 0039
# Correcting points for image: extractor.vi.in_house.appen_000478_page0001.jpg, word: 0048
# Correcting points for image: extractor.vi.in_house.appen_000478_page0001.jpg, word: 0053
# Correcting points for image: extractor.vi.in_house.appen_000478_page0001.jpg, word: 0062
# Correcting points for image: extractor.vi.in_house.appen_000597_page0001.jpg, word: 0001
# Correcting points for image: extractor.vi.in_house.appen_000597_page0001.jpg, word: 0075
# Correcting points for image: extractor.vi.in_house.appen_000726_page0001.jpg, word: 0009
# Correcting points for image: extractor.vi.in_house.appen_000726_page0001.jpg, word: 0019
# Correcting points for image: extractor.vi.in_house.appen_000726_page0001.jpg, word: 0023
# Correcting points for image: extractor.vi.in_house.appen_000726_page0001.jpg, word: 0032
# Correcting points for image: extractor.vi.in_house.appen_000726_page0001.jpg, word: 0046
# Correcting points for image: extractor.vi.in_house.appen_000726_page0001.jpg, word: 0047
# Correcting points for image: extractor.vi.in_house.appen_000726_page0001.jpg, word: 0113
# Correcting points for image: extractor.vi.in_house.appen_000726_page0001.jpg, word: 0185
# Correcting points for image: extractor.vi.in_house.appen_001114_page0001.jpg, word: 0062
# Correcting points for image: extractor.vi.in_house.appen_001114_page0001.jpg, word: 0095
# Correcting points for image: extractor.vi.in_house.appen_001114_page0001.jpg, word: 0102
# Correcting points for image: extractor.vi.in_house.appen_000114_page0001.jpg, word: 0061
# Correcting points for image: extractor.vi.in_house.appen_000114_page0001.jpg, word: 0089
# Correcting points for image: extractor.vi.in_house.appen_000114_page0001.jpg, word: 0098
# Correcting points for image: extractor.vi.in_house.appen_000424_page0001.jpg, word: 0049
# Correcting points for image: extractor.vi.in_house.appen_000424_page0001.jpg, word: 0074
# Correcting points for image: extractor.vi.in_house.appen_001047_page0001.jpg, word: 0043
# Correcting points for image: extractor.vi.in_house.appen_001047_page0001.jpg, word: 0065
# Correcting points for image: extractor.vi.in_house.appen_001015_page0001.jpg, word: 0014
# Correcting points for image: extractor.vi.in_house.appen_001015_page0001.jpg, word: 0067
# Correcting points for image: extractor.vi.in_house.appen_001015_page0001.jpg, word: 0084
# Correcting points for image: extractor.vi.in_house.appen_001015_page0001.jpg, word: 0124
# Correcting points for image: extractor.vi.in_house.appen_001015_page0001.jpg, word: 0125
# Correcting points for image: extractor.vi.in_house.appen_001015_page0001.jpg, word: 0128
# Correcting points for image: extractor.vi.in_house.appen_000044_page0001.jpg, word: 0011
# Correcting points for image: extractor.vi.in_house.appen_000044_page0001.jpg, word: 0022
# Correcting points for image: extractor.vi.in_house.appen_000044_page0001.jpg, word: 0042
# Correcting points for image: extractor.vi.in_house.appen_000044_page0001.jpg, word: 0056
# Correcting points for image: extractor.vi.in_house.appen_000044_page0001.jpg, word: 0061
# Correcting points for image: extractor.vi.in_house.appen_000044_page0001.jpg, word: 0070
# Correcting points for image: extractor.vi.in_house.appen_000496_page0001.jpg, word: 0121
# Correcting points for image: extractor.vi.in_house.appen_000496_page0001.jpg, word: 0153
# Correcting points for image: extractor.vi.in_house.appen_000060_page0001.jpg, word: 0137
# Correcting points for image: extractor.vi.in_house.appen_000735_page0001.jpg, word: 0014
# Correcting points for image: extractor.vi.in_house.appen_000735_page0001.jpg, word: 0015
# Correcting points for image: extractor.vi.in_house.appen_000735_page0001.jpg, word: 0022
# Correcting points for image: extractor.vi.in_house.appen_000735_page0001.jpg, word: 0102
# Correcting points for image: extractor.vi.in_house.appen_000395_page0001.jpg, word: 0083
# Correcting points for image: extractor.vi.in_house.appen_000297_page0001.jpg, word: 0045
# Correcting points for image: extractor.vi.in_house.appen_000743_page0001.jpg, word: 0032
# Correcting points for image: extractor.vi.in_house.appen_000743_page0001.jpg, word: 0039
# Correcting points for image: extractor.vi.in_house.appen_000743_page0001.jpg, word: 0095
# Correcting points for image: extractor.vi.in_house.appen_000512_page0001.jpg, word: 0030
# Correcting points for image: extractor.vi.in_house.appen_000512_page0001.jpg, word: 0047
# Correcting points for image: extractor.vi.in_house.appen_000512_page0001.jpg, word: 0056
# Correcting points for image: extractor.vi.in_house.appen_000512_page0001.jpg, word: 0067
# Correcting points for image: extractor.vi.in_house.appen_000512_page0001.jpg, word: 0083
# Correcting points for image: extractor.vi.in_house.appen_000512_page0001.jpg, word: 0094
# Correcting points for image: extractor.vi.in_house.appen_000620_page0001.jpg, word: 0041
# Correcting points for image: extractor.vi.in_house.appen_000620_page0001.jpg, word: 0061
# Correcting points for image: extractor.vi.in_house.appen_000620_page0001.jpg, word: 0068
# Correcting points for image: extractor.vi.in_house.appen_000620_page0001.jpg, word: 0122
# Correcting points for image: extractor.vi.in_house.appen_000780_page0001.jpg, word: 0045
# Correcting points for image: extractor.vi.in_house.appen_000780_page0001.jpg, word: 0077
# Correcting points for image: extractor.vi.in_house.appen_000780_page0001.jpg, word: 0091
# Correcting points for image: extractor.vi.in_house.appen_000780_page0001.jpg, word: 0093
# Correcting points for image: extractor.vi.in_house.appen_000873_page0001.jpg, word: 0019
# Correcting points for image: extractor.vi.in_house.appen_000873_page0001.jpg, word: 0042
# Correcting points for image: extractor.vi.in_house.appen_000852_page0001.jpg, word: 0093
# Correcting points for image: extractor.vi.in_house.appen_000852_page0001.jpg, word: 0102
# Correcting points for image: extractor.vi.in_house.appen_000852_page0001.jpg, word: 0143
# Correcting points for image: extractor.vi.in_house.appen_000389_page0001.jpg, word: 0027
# Correcting points for image: extractor.vi.in_house.appen_000389_page0001.jpg, word: 0036
# Correcting points for image: extractor.vi.in_house.appen_000389_page0001.jpg, word: 0044
# Correcting points for image: extractor.vi.in_house.appen_000389_page0001.jpg, word: 0052
# Correcting points for image: extractor.vi.in_house.appen_000389_page0001.jpg, word: 0059
# Correcting points for image: extractor.vi.in_house.appen_000795_page0001.jpg, word: 0079
# Correcting points for image: extractor.vi.in_house.appen_000795_page0001.jpg, word: 0092
# Correcting points for image: extractor.vi.in_house.appen_000061_page0001.jpg, word: 0025
# Correcting points for image: extractor.vi.in_house.appen_000061_page0001.jpg, word: 0152
# Correcting points for image: extractor.vi.in_house.appen_001083_page0001.jpg, word: 0061
# Correcting points for image: extractor.vi.in_house.appen_001083_page0001.jpg, word: 0066
# Correcting points for image: extractor.vi.in_house.appen_001083_page0001.jpg, word: 0115
# Correcting points for image: extractor.vi.in_house.appen_001036_page0001.jpg, word: 0051
# Correcting points for image: extractor.vi.in_house.appen_001036_page0001.jpg, word: 0075
# Correcting points for image: extractor.vi.in_house.appen_000118_page0001.jpg, word: 0063
# Correcting points for image: extractor.vi.in_house.appen_000087_page0001.jpg, word: 0016
# Correcting points for image: extractor.vi.in_house.appen_000087_page0001.jpg, word: 0023
# Correcting points for image: extractor.vi.in_house.appen_000087_page0001.jpg, word: 0107
# Correcting points for image: extractor.vi.in_house.appen_000087_page0001.jpg, word: 0115
# Correcting points for image: extractor.vi.in_house.appen_000553_page0001.jpg, word: 0071
# Correcting points for image: extractor.vi.in_house.appen_000357_page0001.jpg, word: 0042
# Correcting points for image: extractor.vi.in_house.appen_001034_page0001.jpg, word: 0068
# Correcting points for image: extractor.vi.in_house.appen_000601_page0001.jpg, word: 0064
# Correcting points for image: extractor.vi.in_house.appen_000601_page0001.jpg, word: 0073
# Correcting points for image: extractor.vi.in_house.appen_001070_page0001.jpg, word: 0037
# Correcting points for image: extractor.vi.in_house.appen_001070_page0001.jpg, word: 0057
# Correcting points for image: extractor.vi.in_house.appen_001070_page0001.jpg, word: 0070
# Correcting points for image: extractor.vi.in_house.appen_001070_page0001.jpg, word: 0079
# Correcting points for image: extractor.vi.in_house.appen_001070_page0001.jpg, word: 0118
# Correcting points for image: extractor.vi.in_house.appen_000737_page0001.jpg, word: 0091
# Correcting points for image: extractor.vi.in_house.appen_000737_page0001.jpg, word: 0096
# Correcting points for image: extractor.vi.in_house.appen_000737_page0001.jpg, word: 0115
# Correcting points for image: extractor.vi.in_house.appen_000657_page0001.jpg, word: 0013
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0022
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0040
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0053
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0062
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0079
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0080
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0107
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0123
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0130
# Correcting points for image: extractor.vi.in_house.appen_000110_page0001.jpg, word: 0131
# Correcting points for image: extractor.vi.in_house.appen_000026_page0001.jpg, word: 0013
# Correcting points for image: extractor.vi.in_house.appen_000026_page0001.jpg, word: 0026
# Correcting points for image: extractor.vi.in_house.appen_000026_page0001.jpg, word: 0045
# Correcting points for image: extractor.vi.in_house.appen_000026_page0001.jpg, word: 0096
# Correcting points for image: extractor.vi.in_house.appen_000844_page0001.jpg, word: 0022
# Correcting points for image: extractor.vi.in_house.appen_000844_page0001.jpg, word: 0028
# Correcting points for image: extractor.vi.in_house.appen_000844_page0001.jpg, word: 0053
# Correcting points for image: extractor.vi.in_house.appen_000725_page0001.jpg, word: 0011
# Correcting points for image: extractor.vi.in_house.appen_000725_page0001.jpg, word: 0038
# Correcting points for image: extractor.vi.in_house.appen_000725_page0001.jpg, word: 0044
# Correcting points for image: extractor.vi.in_house.appen_000725_page0001.jpg, word: 0052
# Correcting points for image: extractor.vi.in_house.appen_000725_page0001.jpg, word: 0059
# Correcting points for image: extractor.vi.in_house.appen_000725_page0001.jpg, word: 0066
# Correcting points for image: extractor.vi.in_house.appen_000100_page0001.jpg, word: 0033
# Correcting points for image: extractor.vi.in_house.appen_000100_page0001.jpg, word: 0039
# Correcting points for image: extractor.vi.in_house.appen_000100_page0001.jpg, word: 0165
# Correcting points for image: extractor.vi.in_house.appen_000590_page0001.jpg, word: 0055
# Corrected JSON saved to: /data/ephemeral/code/data/vietnamese_receipt/ufo/train_corrected.json

# %% [markdown]
# ### "" 없애기.

# %%
import json

# JSON 파일 경로 설정
input_json_path = '/data/ephemeral/code/data/vietnamese_receipt/ufo/train_corrected.json'  # 원본 JSON 파일 경로
output_json_path = '/data/ephemeral/code/data/vietnamese_receipt/ufo/train_corrected_v2.json'  # 수정된 JSON 파일 경로

# JSON 파일 읽기
with open(input_json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# transcription이 빈 문자열인 words 삭제
for image_key, image_value in data['images'].items():
    if 'words' in image_value:
        words_to_delete = [word_key for word_key, word_info in image_value['words'].items() 
                           if 'transcription' in word_info and word_info['transcription'] == ""]
        
        # 찾은 키들을 삭제
        for word_key in words_to_delete:
            del image_value['words'][word_key]

# 수정된 JSON 파일 저장
with open(output_json_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"transcription이 빈 문자열인 words가 삭제된 JSON 파일이 {output_json_path}에 저장되었습니다.")
# Out:
# transcription이 빈 문자열인 words가 삭제된 JSON 파일이 /data/ephemeral/code/data/vietnamese_receipt/ufo/train_corrected_v2.json에 저장되었습니다.
